# %% [markdown]
# # Python Lesson 5: Jupyter Notebook Executable
#
# Click the button below to launch the live execution engine:
#
# ```{thebe-button}

# %%
print()

# %% [markdown]
# 3. Below that Markdown cell, create standard Python **Code cells** containing your code (e.g., `print("Hello from Jupyter!")`).
#
# ---
#
# ## Summary Checklist to Fix Everything
#
# 1. **Rename** `python_course_03.srt` $\rightarrow$ `python_course_03.rst` in your file explorer.
# 2. **Install `nbsphinx`** by running `pip install nbsphinx` in your terminal and updating `requirements.txt` and `content/conf.py`.
# 3. **Verify folder paths** in `index.rst` match your exact folder names on disk.
# 4. Run **`build_local.bat`** and refresh `http://localhost:8000`. All pages—including your Jupyter Notebooks—will render and execute Python cleanly!
